# %% [markdown]
# # TASK 1

# %% [markdown]
# P(A)= Probability that the worker is female =0.46

# %% [markdown]
# P(B)= Probability that the worker is part-time =0.174

# %% [markdown]
# P(A n B)= Probability that the worker is female part-time worker =0.46* 0.25 =0.115

# %% [markdown]
# P(A|B)= Probability that the worker is female if a part-time worker is randomly selected

# %% [markdown]
# P(A|B)= P(A n B)/P(B)= 0.115/0.174= 0.66

# %% [markdown]
# # TASK 2

# %% [markdown]
# P(A) = Probability that the respondent believes that reduction in noise will increase productivity =0.7

# %% [markdown]
# P(B)= Probability that the respondent believes that more storage space will increase productivity =0.67

# %% [markdown]
# P(A n B)= Probability that respondent believes that more storage space and reduction in noise will increase productivity =0.56

# %% [markdown]
# P(A|B)= Probability that a randomly selected worker who believes that reducing noise will increase productivity also believes that more storage space will increase productivity

# %% [markdown]
# P(B|A)= P(A n B)/ P(A)= 0.56/0.7= 0.8

# %% [markdown]
# # TASK 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st
NPD=pd.read_csv('DS1_C5_S3_Sampling_Practice_GamesSales_Data.csv')
NPD
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...

# %%
# Task 3.1
# 3.1.1
s_data1=NPD.sample(n=30, replace=False, random_state=0)
s_data1
# Out:
#                                               Game  Year             Genre  \
# 540     Nitroplus Blasterz: Heroines Infinite Duel  2017          Fighting
# 467                       Shantae: Half-Genie Hero  2018          Platform
# 355                    Prototype: Biohazard Bundle  2018            Action
# 172       Disney Infinity 2.0: Marvel Super Heroes  2016  Action-Adventure
# 637                            Rugby League Live 3  2017            Sports
# 665                         Skullgirls: 2nd Encore  2018          Fighting
# 113                                EA Sports UFC 2  2018            Sports
# 40                      Assassin's Creed Syndicate  2017            Action
# 363  Naruto Shippuden: Ultimate Ninja Storm Legacy  2019          Fighting
# 541                  Nobunaga's Ambition: Creation  2016          Strategy
# 229                               TrackMania Turbo  2018            Racing
# ...

# %%
#3.1.2
s_data2=NPD.sample(n=30, replace= True, random_state=0)
s_data2
# Out:
#                                           Game  Year             Genre  \
# 684                              Occultic;Nine  2019         Adventure
# 559                              Ben 10 (2019)  2019            Action
# 629             Zero Escape: Zero Time Dilemma  2019         Adventure
# 192                            LEGO The Hobbit  2016  Action-Adventure
# 707            The Escapists: The Walking Dead  2018            Action
# 359                              Dead Rising 4  2019  Action-Adventure
# 9                                    Fallout 4  2017      Role-Playing
# 277                            Just Dance 2018  2019             Music
# 599                      Infamous: First Light  2016            Action
# 70                                No Man's Sky  2018  Action-Adventure
# 472                              Loading Human  2018         Adventure
# 600                                   Raiden V  2019            Action
# ...

# %%
#3.1.3
import numpy as np
index=np.arange(0, len(NPD), step=10)
s_data3=NPD.iloc[index]
s_data3
# Out:
#                                             Game  Year      Genre  \
# 0                             Grand Theft Auto V  2016     Action
# 10                                       FIFA 16  2017     Sports
# 20        Uncharted: The Nathan Drake Collection  2017     Action
# 30                          Call of Duty: Ghosts  2015    Shooter
# 40                    Assassin's Creed Syndicate  2017     Action
# ..                                           ...   ...        ...
# 660          The Inner World: The Last Wind Monk  2019     Puzzle
# 670     Touhou Shinhiroku: Urban Legend in Limbo  2018   Fighting
# 680                       Hakoniwa Company Works  2019   Strategy
# 690                               Zombie Vikings  2018     Action
# 700  Date-A-Live Twin Edition: Rio Reincarnation  2019  Adventure
#
#                        Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0                 Rockstar Games                    6.06             9.71
# ...

# %%
#3.1.4
gr_data1=NPD.groupby(by=['Year'])['Genre'].value_counts()
gr_data2=NPD.groupby(['Year','Genre'])
s_data4=pd.DataFrame()

for i in gr_data1.index:
    data=gr_data2.get_group(i)
    sample_data=data.sample(n=5, replace=True, random_state= 1)
    s_data4=s_data4.append(sample_data, ignore_index= True)
    
s_data4
# Out:
#                Game  Year     Genre        Publisher  North_America_Sales_M$  \
# 0          NBA 2K14  2015    Sports        2K Sports                    0.91
# 1       NBA Live 14  2015    Sports        EA Sports                    0.17
# 2    FIFA Soccer 14  2015    Sports        EA Sports                    0.62
# 3    FIFA Soccer 14  2015    Sports        EA Sports                    0.62
# 4       NBA Live 14  2015    Sports        EA Sports                    0.17
# ..              ...   ...       ...              ...                     ...
# 410         Armello  2020  Strategy  League of Geeks                    0.02
# 411         Armello  2020  Strategy  League of Geeks                    0.02
# 412         Armello  2020  Strategy  League of Geeks                    0.02
# 413         Armello  2020  Strategy  League of Geeks                    0.02
# 414         Armello  2020  Strategy  League of Geeks                    0.02
#
# ...

# %%
# TASK 3.1.5
gr_data3=NPD.groupby('Year')
year=[2015,2020]
s_data5=pd.DataFrame()

for y in year:
    data1=gr_data3.get_group(y)
    sample_data1=data1.sample(n=50, replace=True, random_state=1)
    s_data5=s_data5.append(sample_data1, ignore_index=True)
s_data5
# Out:
#                                                  Game  Year         Genre  \
# 0                               Need for Speed Rivals  2015        Racing
# 1                                     Just Dance 2014  2015         Music
# 2                               Skylanders SWAP Force  2015          Misc
# 3                                            NBA 2K14  2015        Sports
# 4                                         Putty Squad  2015      Platform
# ..                                                ...   ...           ...
# 95                          Kingdom Come: Deliverance  2020  Role-Playing
# 96  Monster Energy Supercross - The Official Video...  2020        Racing
# 97                                   Hokuto ga Gotoku  2020        Action
# 98                  Naruto to Boruto: Shinobi Striker  2020        Action
# 99                                             Vampyr  2020  Role-Playing
#
#                  Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %%
gr_data4=s_data5.groupby('Genre')
genre=['Sports','Action']
s_data6=pd.DataFrame()

for g in genre:
    data2=gr_data4.get_group(g)
    sample_data2=data2.sample(n=16, replace=True, random_state=1)
    s_data6=s_data6.append(sample_data2, ignore_index= True)
s_data6
# Out:
#                                  Game  Year   Genre  \
# 0                         NBA Live 14  2015  Sports
# 1                     EA Sports UFC 3  2020  Sports
# 2                     MLB The Show 18  2020  Sports
# 3                         NBA Live 14  2015  Sports
# 4                     MLB The Show 18  2020  Sports
# 5                     EA Sports UFC 3  2020  Sports
# 6                         NBA Live 14  2015  Sports
# 7                            NBA 2K14  2015  Sports
# 8                            NBA 2K14  2015  Sports
# 9                         NBA Live 14  2015  Sports
# 10                    MLB The Show 18  2020  Sports
# 11                        NBA Live 14  2015  Sports
# 12                    MLB The Show 18  2020  Sports
# 13                    MLB The Show 18  2020  Sports
# 14                     FIFA Soccer 14  2015  Sports
# 15                    MLB The Show 18  2020  Sports
# 16  Naruto to Boruto: Shinobi Striker  2020  Action
# ...

# %%
# TASK 3.2
# Making samples
S1=NPD.sample(n=10, random_state=1)
S2=NPD.sample(n=20, random_state=1)
S3=NPD.sample(n=30, random_state=1)
S4=NPD.sample(n=40, random_state=1)

# %%
# Sample Distribution
row_head=['Sample','Mean','Median','Standard Deviation']

# %%
S1M=['Sample data(n=10)',S1['Global_Sales_M$'].mean(),S1['Global_Sales_M$'].median(),S1['Global_Sales_M$'].std()]
S2M=['Sample data(n=20)',S2['Global_Sales_M$'].mean(),S2['Global_Sales_M$'].median(),S2['Global_Sales_M$'].std()]
S3M=['Sample data(n=30)',S3['Global_Sales_M$'].mean(),S3['Global_Sales_M$'].median(),S3['Global_Sales_M$'].std()]
S4M=['Sample data(n=40)',S4['Global_Sales_M$'].mean(),S4['Global_Sales_M$'].median(),S4['Global_Sales_M$'].std()]
PolM=['Population',NPD['Global_Sales_M$'].mean(),NPD['Global_Sales_M$'].median(),NPD['Global_Sales_M$'].std()]

# %%
SD=pd.DataFrame([S1M,S2M,S3M,S4M,PolM], columns=row_head)
SD
# Out:
#               Sample      Mean  Median  Standard Deviation
# 0  Sample data(n=10)  0.580000   0.160            0.776431
# 1  Sample data(n=20)  1.047000   0.380            1.950396
# 2  Sample data(n=30)  1.045333   0.185            1.838631
# 3  Sample data(n=40)  0.877750   0.155            1.665110
# 4         Population  0.839803   0.170            1.853915

# %%
# Shape of Distribution
#For Population Data
plt.hist(NPD['Global_Sales_M$'], bins=6)
plt.show()

# %%
#For Stratified Sampled Data
plt.hist(s_data4['Global_Sales_M$'], bins=6)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# The Stratified sample supports the central limit theorem as the distribution is a near normal distribution.
