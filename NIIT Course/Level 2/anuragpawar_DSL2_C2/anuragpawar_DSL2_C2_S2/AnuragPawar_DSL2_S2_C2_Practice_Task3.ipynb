# %%
import pandas as pd

# %%
df=pd.read_csv("RestaurantsData.csv")
df
# Out:
#               RestaurantName                       _id address line 2 outcode  \
# 0                .CN Chinese  55f14312c7447c3da7051b26        Cardiff    CF24
# 1                     @ Thai  55f14312c7447c3da7051b27          Essex     SS9
# 2          @ Thai Restaurant  55f14312c7447c3da7051b28         London      W6
# 3          @ Thai Restaurant  55f14312c7447c3da7051b29         London      W6
# 4                @Indian.com  55f14312c7447c3da7051b2a      Broughton     CH4
# ...                      ...                       ...            ...     ...
# 2543  Blue Bengal Restaurant  55f14313c7447c3da7052515           Kent     BR4
# 2544  Blue Bengal Restaurant  55f14313c7447c3da7052516           Kent     BR4
# 2545                Blue Box  55f14313c7447c3da7052517    Southampton    SO14
# 2546    Blue Breeze Fish Bar  55f14313c7447c3da7052518      Leicester     LE3
# 2547    Blue Breeze Fish Bar  55f14313c7447c3da7052519      Leicester     LE3
#
#      postcode rating  type_of_food
# 0         3JH      5       Chinese
# 1         5PT    5.5          Thai
# 2         8NX    4.5          Thai
# 3         8NX    4.5          Thai
# 4         0QR      6         Curry
# ...       ...    ...           ...
# 2543      0LT    4.5         Curry
# 2544      0LT    4.5         Curry
# 2545      0JZ      5         Grill
# 2546      9NG    5.5  Fish & Chips
# 2547      9NG    5.5  Fish & Chips
#
# [2548 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize= (10, 7))
ax = sns.countplot(x = df["type_of_food"])
ax.set_xticklabels(ax.get_xticklabels(), rotation = 90 , ha = "center")
plt.show()
